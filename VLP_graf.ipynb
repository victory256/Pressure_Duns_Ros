# %%
from Pressure_Duns_Ros import *
import matplotlib.pyplot as plt
lag = 100
x = range(1000, 2000, lag)
y = []
for i in x:
    y.append (calc_pressure(i, 283, 0))

fig = plt.figure()
plt.title("VLP")
plt.xlabel("q_ж, ст.м^3/сут")
plt.ylabel("Рзаб, бар")
plt.plot(x, y)
